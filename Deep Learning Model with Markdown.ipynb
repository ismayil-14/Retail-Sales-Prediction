# %% [markdown]
# **Importing essential Datasets and Libraries**

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, PowerTransformer
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from tensorflow.keras.layers import LeakyReLU, Dropout
from tensorflow.keras import backend as K
import kerastuner as kt
# Out:
# <ipython-input-7-80049c0691d3>:9: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   import kerastuner as kt

# %%
df_original = pd.read_csv('preprocessed_table.csv')

# %%
df_original
# Out:
#         Day  Month  Year  Week        Date  Store  Dept  Type    Size  \
# 0         5      2  2010     5  2010-02-05      1     1     1  151315
# 1         5      2  2010     5  2010-02-05      1     2     1  151315
# 2         5      2  2010     5  2010-02-05      1     3     1  151315
# 3         5      2  2010     5  2010-02-05      1     4     1  151315
# 4         5      2  2010     5  2010-02-05      1     5     1  151315
# ...     ...    ...   ...   ...         ...    ...   ...   ...     ...
# 551474   28      6  2013    26  2013-06-28     45    98     2  118221
# 551475    5      7  2013    27  2013-07-05     45    98     2  118221
# 551476   12      7  2013    28  2013-07-12     45    98     2  118221
# 551477   19      7  2013    29  2013-07-19     45    98     2  118221
# 551478   26      7  2013    30  2013-07-26     45    98     2  118221
#
#         Temperature  ...         CPI  Unemployment  IsHoliday  Weekly_Sales  \
# 0             42.31  ...  211.096358      8.106000          0      24924.50
# 1             42.31  ...  211.096358      8.106000          0      50605.27
# 2             42.31  ...  211.096358      8.106000          0      13740.12
# 3             42.31  ...  211.096358      8.106000          0      39954.04
# 4             42.31  ...  211.096358      8.106000          0      32229.38
# ...             ...  ...         ...           ...        ...           ...
# 551474        76.05  ...  194.049252      8.299803          0           NaN
# 551475        77.50  ...  194.118327      8.295893          0           NaN
# 551476        79.37  ...  194.187760      8.291982          0           NaN
# 551477        82.84  ...  194.257397      8.288071          0           NaN
# 551478        76.06  ...  194.327149      8.284160          0           NaN
#
#         Markdown  MarkDown1  MarkDown2  MarkDown3   MarkDown4  MarkDown5
# 0              0  5502.9669   1474.233   236.8201  14827.2141  5103.4707
# 1              0  5502.9669   1474.233   236.8201  14827.2141  5103.4707
# 2              0  5502.9669   1474.233   236.8201  14827.2141  5103.4707
# 3              0  5502.9669   1474.233   236.8201  14827.2141  5103.4707
# 4              0  5502.9669   1474.233   236.8201  14827.2141  5103.4707
# ...          ...        ...        ...        ...         ...        ...
# 551474         1  4842.2900    975.030     3.0000   2449.9700  3169.6900
# 551475         1  9090.4800   2268.580   582.7400   5797.4700  1514.9300
# 551476         1  3789.9400   1827.310    85.7200    744.8400  2150.3600
# 551477         1  2961.4900   1047.070   204.1900    363.0000  1059.4600
# 551478         1   212.0200    851.730     2.0600     10.8800  1864.5700
#
# [551479 rows x 21 columns]

# %% [markdown]
# **Filtering null values and non-null value in different dataframes**

# %%
df_null = df_original[df_original["Weekly_Sales"].isnull()]
df_null.reset_index(drop=True, inplace=True)
print("1.null shape",df_null.shape)

df = df_original[df_original["Weekly_Sales"].notnull()]
df.reset_index(drop=True, inplace=True)
print("2.not null ",df.shape)
# Out:
# 1.null shape (131267, 21)
# 2.not null  (420212, 21)

# %% [markdown]
# **Removing Outliers in Weekly_Sales**

# %%
Q1 = df['Weekly_Sales'].quantile(0.25)
Q3 = df['Weekly_Sales'].quantile(0.75)

IQR = Q3 - Q1

l = Q1 - 1.5 * IQR
u = Q3 + 1.5 * IQR

df = df[(df['Weekly_Sales'] >= l) & (df['Weekly_Sales'] <= u)]

# %% [markdown]
# **Creating new feature -> Weekly Sales Lag.**
#
# **This feature will extract the previous week's sales Data**

# %%
df['Weekly_Sales_Lag1'] = df['Weekly_Sales'].shift(1)

# %% [markdown]
# **1st Week's will be missing due to lag feature. So filling it with 1st week's mean value.**

# %%
df1 = df[df["Store"]==1]

# %% [markdown]
# **Selecting only appropriate features with Markdown that is necessary to build a perfect model.**
#
# **Square rooting the Weekly_Sales column to reduce skewness.**

# %%
features = ['Store','Type','Size','Day', 'Month', 'Year', 'Dept', 'Temperature', 'Fuel_Price', 'CPI', 'Unemployment', 'IsHoliday','MarkDown1','MarkDown2','MarkDown3','MarkDown4','MarkDown5', 'Weekly_Sales_Lag1']
x = df[features]
y = df['Weekly_Sales']
x.fillna(df1["Weekly_Sales_Lag1"].mean(),inplace = True)
y_transformed = np.sqrt(y)

scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

x_train, x_test, y_train, y_test = train_test_split(x_scaled, y_transformed, test_size=0.2, random_state=42)
# Out:
# <ipython-input-14-1a874cbb0928>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x.fillna(df1["Weekly_Sales_Lag1"].mean(),inplace = True)

# %%
# Defining the ANN model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(512, activation='relu', input_shape=(x_train.shape[1],), kernel_regularizer=tf.keras.regularizers.l2(0.001)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1, activation='linear')
])

# Compile the model with learning rate
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005), loss='mean_squared_error')

# Train the model with EarlyStopping and Reducing the Learning Rate
history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=100, batch_size=32, callbacks=[
    tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True),
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10)
])


y_pred = model.predict(x_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

metrics = {
    'R2': r2,
    'Mean Absolute Error': mae,
    'Mean Squared Error': mse,
    'Root Mean Squared Error': rmse
}

print(metrics)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 36s 3ms/step - loss: 2595.8896 - val_loss: 1832.4745 - learning_rate: 5.0000e-04
# Epoch 2/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 34s 3ms/step - loss: 1903.1234 - val_loss: 1684.9916 - learning_rate: 5.0000e-04
# Epoch 3/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 25s 3ms/step - loss: 1801.9327 - val_loss: 1606.4099 - learning_rate: 5.0000e-04
# Epoch 4/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - loss: 1750.7939 - val_loss: 1548.5500 - learning_rate: 5.0000e-04
# Epoch 5/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - loss: 1701.2429 - val_loss: 1517.9486 - learning_rate: 5.0000e-04
# Epoch 6/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 25s 3ms/step - loss: 1667.4309 - val_loss: 1431.4082 - learning_rate: 5.0000e-04
# Epoch 7/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 39s 2ms/step - loss: 1628.7946 - val_loss: 1385.6055 - learning_rate: 5.0000e-04
# Epoch 8/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 24s 3ms/step - loss: 1590.9332 - val_loss: 1355.6893 - learning_rate: 5.0000e-04
# Epoch 9/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 41s 2ms/step - loss: 1555.5194 - val_loss: 1293.0875 - learning_rate: 5.0000e-04
# Epoch 10/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 40s 2ms/step - loss: 1524.6273 - val_loss: 1288.4458 - learning_rate: 5.0000e-04
# Epoch 11/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 43s 3ms/step - loss: 1487.0542 - val_loss: 1206.7679 - learning_rate: 5.0000e-04
# Epoch 12/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 41s 3ms/step - loss: 1461.7802 - val_loss: 1234.1816 - learning_rate: 5.0000e-04
# Epoch 13/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 25s 3ms/step - loss: 1436.7091 - val_loss: 1169.1335 - learning_rate: 5.0000e-04
# Epoch 14/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 39s 2ms/step - loss: 1414.8688 - val_loss: 1134.7601 - learning_rate: 5.0000e-04
# Epoch 15/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 42s 2ms/step - loss: 1397.5500 - val_loss: 1149.2146 - learning_rate: 5.0000e-04
# Epoch 16/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - loss: 1376.2794 - val_loss: 1098.8375 - learning_rate: 5.0000e-04
# Epoch 17/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 25s 3ms/step - loss: 1354.4583 - val_loss: 1098.8175 - learning_rate: 5.0000e-04
# Epoch 18/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 39s 2ms/step - loss: 1347.9242 - val_loss: 1060.4734 - learning_rate: 5.0000e-04
# Epoch 19/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - loss: 1324.7054 - val_loss: 1049.4437 - learning_rate: 5.0000e-04
# Epoch 20/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step - loss: 1311.3889 - val_loss: 1041.7643 - learning_rate: 5.0000e-04
# Epoch 21/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 41s 2ms/step - loss: 1293.9982 - val_loss: 1022.8167 - learning_rate: 5.0000e-04
# Epoch 22/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 40s 2ms/step - loss: 1289.1947 - val_loss: 992.3765 - learning_rate: 5.0000e-04
# Epoch 23/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 43s 3ms/step - loss: 1277.6771 - val_loss: 997.6188 - learning_rate: 5.0000e-04
# Epoch 24/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 38s 2ms/step - loss: 1261.0360 - val_loss: 970.9160 - learning_rate: 5.0000e-04
# Epoch 25/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - loss: 1247.7266 - val_loss: 969.9034 - learning_rate: 5.0000e-04
# Epoch 26/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 43s 3ms/step - loss: 1238.7587 - val_loss: 963.4943 - learning_rate: 5.0000e-04
# Epoch 27/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 41s 3ms/step - loss: 1225.6882 - val_loss: 948.4610 - learning_rate: 5.0000e-04
# Epoch 28/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 40s 3ms/step - loss: 1231.2170 - val_loss: 899.6545 - learning_rate: 5.0000e-04
# Epoch 29/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 40s 2ms/step - loss: 1203.6211 - val_loss: 930.4451 - learning_rate: 5.0000e-04
# Epoch 30/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - loss: 1217.0338 - val_loss: 909.4543 - learning_rate: 5.0000e-04
# Epoch 31/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 43s 2ms/step - loss: 1198.1608 - val_loss: 913.8599 - learning_rate: 5.0000e-04
# Epoch 32/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - loss: 1197.8606 - val_loss: 866.2236 - learning_rate: 5.0000e-04
# Epoch 33/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - loss: 1188.4152 - val_loss: 876.3977 - learning_rate: 5.0000e-04
# Epoch 34/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 43s 3ms/step - loss: 1174.3110 - val_loss: 861.6690 - learning_rate: 5.0000e-04
# Epoch 35/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - loss: 1162.2161 - val_loss: 842.8558 - learning_rate: 5.0000e-04
# Epoch 36/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 43s 3ms/step - loss: 1154.2430 - val_loss: 870.9286 - learning_rate: 5.0000e-04
# Epoch 37/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 25s 3ms/step - loss: 1160.5907 - val_loss: 834.5273 - learning_rate: 5.0000e-04
# Epoch 38/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step - loss: 1147.0525 - val_loss: 811.5048 - learning_rate: 5.0000e-04
# Epoch 39/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step - loss: 1134.8070 - val_loss: 795.9679 - learning_rate: 5.0000e-04
# Epoch 40/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 41s 2ms/step - loss: 1144.5808 - val_loss: 808.6443 - learning_rate: 5.0000e-04
# Epoch 41/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 24s 3ms/step - loss: 1121.0472 - val_loss: 810.2633 - learning_rate: 5.0000e-04
# Epoch 42/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 41s 3ms/step - loss: 1119.5673 - val_loss: 826.6672 - learning_rate: 5.0000e-04
# Epoch 43/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 24s 3ms/step - loss: 1110.8850 - val_loss: 795.4778 - learning_rate: 5.0000e-04
# Epoch 44/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - loss: 1112.5566 - val_loss: 769.9282 - learning_rate: 5.0000e-04
# Epoch 45/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 26s 3ms/step - loss: 1105.5242 - val_loss: 767.1100 - learning_rate: 5.0000e-04
# Epoch 46/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - loss: 1094.9374 - val_loss: 761.8212 - learning_rate: 5.0000e-04
# Epoch 47/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 43s 3ms/step - loss: 1101.0535 - val_loss: 783.5542 - learning_rate: 5.0000e-04
# Epoch 48/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 25s 3ms/step - loss: 1089.9272 - val_loss: 765.2822 - learning_rate: 5.0000e-04
# Epoch 49/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 24s 3ms/step - loss: 1085.6625 - val_loss: 761.4092 - learning_rate: 5.0000e-04
# Epoch 50/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 42s 3ms/step - loss: 1081.7853 - val_loss: 749.6342 - learning_rate: 5.0000e-04
# Epoch 51/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 39s 2ms/step - loss: 1079.9834 - val_loss: 729.3035 - learning_rate: 5.0000e-04
# Epoch 52/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 43s 3ms/step - loss: 1073.5674 - val_loss: 750.1276 - learning_rate: 5.0000e-04
# Epoch 53/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 38s 2ms/step - loss: 1057.2001 - val_loss: 743.1765 - learning_rate: 5.0000e-04
# Epoch 54/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 25s 3ms/step - loss: 1065.9130 - val_loss: 758.1320 - learning_rate: 5.0000e-04
# Epoch 55/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 40s 3ms/step - loss: 1057.4027 - val_loss: 749.4159 - learning_rate: 5.0000e-04
# Epoch 56/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 40s 2ms/step - loss: 1054.5715 - val_loss: 752.6534 - learning_rate: 5.0000e-04
# Epoch 57/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - loss: 1060.9949 - val_loss: 741.5998 - learning_rate: 5.0000e-04
# Epoch 58/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - loss: 1053.0587 - val_loss: 718.4306 - learning_rate: 5.0000e-04
# Epoch 59/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 42s 2ms/step - loss: 1042.8156 - val_loss: 710.3775 - learning_rate: 5.0000e-04
# Epoch 60/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 25s 3ms/step - loss: 1045.8110 - val_loss: 705.9622 - learning_rate: 5.0000e-04
# Epoch 61/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step - loss: 1040.3997 - val_loss: 707.6912 - learning_rate: 5.0000e-04
# Epoch 62/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step - loss: 1035.0983 - val_loss: 700.1834 - learning_rate: 5.0000e-04
# Epoch 63/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 24s 3ms/step - loss: 1024.6935 - val_loss: 689.1541 - learning_rate: 5.0000e-04
# Epoch 64/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 41s 2ms/step - loss: 1021.5601 - val_loss: 723.0113 - learning_rate: 5.0000e-04
# Epoch 65/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step - loss: 1026.6052 - val_loss: 711.6058 - learning_rate: 5.0000e-04
# Epoch 66/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 41s 2ms/step - loss: 1030.2194 - val_loss: 699.6622 - learning_rate: 5.0000e-04
# Epoch 67/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 42s 3ms/step - loss: 1029.3959 - val_loss: 674.4662 - learning_rate: 5.0000e-04
# Epoch 68/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 41s 3ms/step - loss: 1003.3939 - val_loss: 686.0294 - learning_rate: 5.0000e-04
# Epoch 69/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 39s 2ms/step - loss: 1005.4783 - val_loss: 682.1163 - learning_rate: 5.0000e-04
# Epoch 70/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 25s 3ms/step - loss: 1015.4313 - val_loss: 691.5338 - learning_rate: 5.0000e-04
# Epoch 71/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step - loss: 1006.4578 - val_loss: 663.1974 - learning_rate: 5.0000e-04
# Epoch 72/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - loss: 1002.7825 - val_loss: 681.8381 - learning_rate: 5.0000e-04
# Epoch 73/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - loss: 1002.7691 - val_loss: 661.1300 - learning_rate: 5.0000e-04
# Epoch 74/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 43s 3ms/step - loss: 1003.3093 - val_loss: 668.5414 - learning_rate: 5.0000e-04
# Epoch 75/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - loss: 997.7410 - val_loss: 660.1377 - learning_rate: 5.0000e-04
# Epoch 76/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - loss: 999.6401 - val_loss: 673.8306 - learning_rate: 5.0000e-04
# Epoch 77/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 43s 3ms/step - loss: 995.1304 - val_loss: 656.7191 - learning_rate: 5.0000e-04
# Epoch 78/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 39s 2ms/step - loss: 984.3116 - val_loss: 672.8872 - learning_rate: 5.0000e-04
# Epoch 79/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - loss: 986.4981 - val_loss: 653.3246 - learning_rate: 5.0000e-04
# Epoch 80/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 43s 3ms/step - loss: 984.0777 - val_loss: 653.4155 - learning_rate: 5.0000e-04
# Epoch 81/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 39s 2ms/step - loss: 977.3102 - val_loss: 673.7673 - learning_rate: 5.0000e-04
# Epoch 82/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 24s 3ms/step - loss: 990.9426 - val_loss: 644.6552 - learning_rate: 5.0000e-04
# Epoch 83/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - loss: 972.3937 - val_loss: 643.9869 - learning_rate: 5.0000e-04
# Epoch 84/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 25s 3ms/step - loss: 979.7845 - val_loss: 653.3303 - learning_rate: 5.0000e-04
# Epoch 85/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - loss: 978.7656 - val_loss: 642.3548 - learning_rate: 5.0000e-04
# Epoch 86/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 43s 3ms/step - loss: 968.5701 - val_loss: 627.6763 - learning_rate: 5.0000e-04
# Epoch 87/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 41s 3ms/step - loss: 962.4193 - val_loss: 641.8992 - learning_rate: 5.0000e-04
# Epoch 88/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - loss: 965.3701 - val_loss: 640.5200 - learning_rate: 5.0000e-04
# Epoch 89/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 24s 3ms/step - loss: 969.6736 - val_loss: 619.2990 - learning_rate: 5.0000e-04
# Epoch 90/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - loss: 976.7004 - val_loss: 631.9509 - learning_rate: 5.0000e-04
# Epoch 91/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 43s 3ms/step - loss: 961.7958 - val_loss: 649.7557 - learning_rate: 5.0000e-04
# Epoch 92/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 42s 3ms/step - loss: 951.3342 - val_loss: 638.0672 - learning_rate: 5.0000e-04
# Epoch 93/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 42s 3ms/step - loss: 955.4673 - val_loss: 639.1258 - learning_rate: 5.0000e-04
# Epoch 94/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 41s 3ms/step - loss: 954.5012 - val_loss: 626.1281 - learning_rate: 5.0000e-04
# Epoch 95/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - loss: 953.4606 - val_loss: 620.1714 - learning_rate: 5.0000e-04
# Epoch 96/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - loss: 953.7757 - val_loss: 627.8884 - learning_rate: 5.0000e-04
# Epoch 97/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 24s 3ms/step - loss: 954.6641 - val_loss: 612.7051 - learning_rate: 5.0000e-04
# Epoch 98/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 25s 3ms/step - loss: 950.9080 - val_loss: 634.3121 - learning_rate: 5.0000e-04
# Epoch 99/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 39s 2ms/step - loss: 948.2998 - val_loss: 617.6308 - learning_rate: 5.0000e-04
# Epoch 100/100
# 9621/9621 ━━━━━━━━━━━━━━━━━━━━ 25s 3ms/step - loss: 941.2209 - val_loss: 622.2692 - learning_rate: 5.0000e-04
# 2406/2406 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step
# {'R2': 0.8086934625187323, 'Mean Absolute Error': 16.881886976303655, 'Mean Squared Error': 585.3373904089227, 'Root Mean Squared Error': 24.193746927851475}

# %% [markdown]
# **Saving the model to find the null values**

# %%
import pickle

# %%
with open("deep_learning_with_markdown.pkl", 'wb') as file:
    pickle.dump(model, file)

# %%
with open("scalar_with_markdown.pkl",'wb') as f:
    pickle.dump(scaler, f)
